# %% [markdown]
# ### Name(s)
# ###Tejashwini Vemavarapu
# ###Harikhumar Prabakaran
# ###Rajendra Goparaju
# ### Due Date
# ###11/28/2023
# ### Class and Professor
# ### Computation and Visualization, Satwik Kamrathi

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### **Descriptive Analysis**
# "Descriptive Analysis involves summarizing and describing the main features of the dataset. It focuses on organizing and presenting the data in a meaningful way, often using measures such as mean, median, mode, and standard deviation. It provides an overview of the data and helps identify patterns or trends."

# %%
#Decriptive Analysis here

#displaying the first row of the dataset
import pandas as pd
import numpy as np
file_path = '/content/Motor_Vehicle_Collisions_-_Crashes.csv'
df = pd.read_csv(file_path)


print("First row of the dataset:")
print(df.head(1))
# Out:
# First row of the dataset:
#    CRASH DATE CRASH TIME BOROUGH  ZIP CODE  LATITUDE  LONGITUDE LOCATION  \
# 0  09/11/2021       2:39     NaN       NaN       NaN        NaN      NaN
#
#           ON STREET NAME CROSS STREET NAME OFF STREET NAME  ...  \
# 0  WHITESTONE EXPRESSWAY         20 AVENUE             NaN  ...
#
#    CONTRIBUTING FACTOR VEHICLE 2  CONTRIBUTING FACTOR VEHICLE 3  \
# 0                    Unspecified                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 4  CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  \
# 0                            NaN                            NaN     4455765.0
#
#    VEHICLE TYPE CODE 1  VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3  \
# 0                Sedan                Sedan                  NaN
#
#   VEHICLE TYPE CODE 4 VEHICLE TYPE CODE 5
# 0                 NaN                 NaN
#
# [1 rows x 29 columns]

# %%
#finding all columns
df.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %%
#finding the data types of all columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5552 entries, 0 to 5551
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   CRASH DATE                     5552 non-null   object
#  1   CRASH TIME                     5552 non-null   object
#  2   BOROUGH                        3677 non-null   object
#  3   ZIP CODE                       3674 non-null   float64
#  4   LATITUDE                       5097 non-null   float64
#  5   LONGITUDE                      5096 non-null   float64
#  6   LOCATION                       5096 non-null   object
#  7   ON STREET NAME                 4059 non-null   object
#  8   CROSS STREET NAME              2618 non-null   object
#  9   OFF STREET NAME                1492 non-null   object
#  10  NUMBER OF PERSONS INJURED      5551 non-null   float64
#  11  NUMBER OF PERSONS KILLED       5551 non-null   float64
# ...

# %%
#finding the number of unique values in each column
df.nunique()
# Out:
# CRASH DATE                        181
# CRASH TIME                       1142
# BOROUGH                             5
# ZIP CODE                          177
# LATITUDE                         4460
# LONGITUDE                        4320
# LOCATION                         4621
# ON STREET NAME                   1410
# CROSS STREET NAME                1353
# OFF STREET NAME                  1473
# NUMBER OF PERSONS INJURED           9
# NUMBER OF PERSONS KILLED            3
# NUMBER OF PEDESTRIANS INJURED       3
# NUMBER OF PEDESTRIANS KILLED        2
# NUMBER OF CYCLIST INJURED           3
# NUMBER OF CYCLIST KILLED            2
# NUMBER OF MOTORIST INJURED          9
# NUMBER OF MOTORIST KILLED           3
# CONTRIBUTING FACTOR VEHICLE 1      45
# CONTRIBUTING FACTOR VEHICLE 2      25
# CONTRIBUTING FACTOR VEHICLE 3      11
# CONTRIBUTING FACTOR VEHICLE 4       4
# CONTRIBUTING FACTOR VEHICLE 5       3
# COLLISION_ID                     5551
# VEHICLE TYPE CODE 1                70
# ...

# %%
#finding the count of all contributing factors


contributing_factor_counts = df['CONTRIBUTING FACTOR VEHICLE 1'].value_counts()


print("CONTRIBUTING FACTORS :")
print(contributing_factor_counts)
# Out:
# CONTRIBUTING FACTORS :
# Driver Inattention/Distraction                           91850
# Unspecified                                              91597
# Following Too Closely                                    26072
# Failure to Yield Right-of-Way                            24675
# Passing or Lane Usage Improper                           15664
# Passing Too Closely                                      13948
# Backing Unsafely                                         12894
# Unsafe Speed                                             10563
# Other Vehicular                                          10287
# Traffic Control Disregarded                               8727
# Unsafe Lane Changing                                      8703
# Turning Improperly                                        7725
# Driver Inexperience                                       6514
# Reaction to Uninvolved Vehicle                            5392
# Alcohol Involvement                                       5211
# ...

# %%
# Summarizing the dataset with descriptive statistics
df.describe()
# Out:
#             ZIP CODE       LATITUDE      LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  240007.000000  336851.000000  336851.000000              367264.000000
# mean    10896.797835      40.415521     -73.350435                   0.416431
# std       523.771396       3.543257       6.429536                   0.765085
# min     10000.000000       0.000000     -74.254845                   0.000000
# 25%     10457.000000      40.666500     -73.961400                   0.000000
# 50%     11208.000000      40.716020     -73.918610                   0.000000
# 75%     11249.000000      40.784096     -73.863830                   1.000000
# max     11697.000000      40.912884       0.000000                  40.000000
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count             367265.000000                  367265.000000
# mean                   0.002244                       0.065174
# std                    0.049781                       0.259008
# ...

# %%
most_common_vehicle_type = df['VEHICLE TYPE CODE 1'].value_counts().idxmax()

# count of accidents for the most common vehicle type
count_most_common_vehicle_type = df['VEHICLE TYPE CODE 1'].value_counts().max()

#the most common vehicle type and its count of accidents
print(f"The vehicle type code with the most accidents is: {most_common_vehicle_type}")
print(f"Number of accidents: {count_most_common_vehicle_type}")
# Out:
# The vehicle type code with the most accidents is: Sedan
# Number of accidents: 170516

# %%
df.shape
# Out:
# (367265, 29)

# %% [markdown]
# ### **Exploratory Analysis**
# "Exploratory Analysis focuses on exploring and understanding the data without preconceived hypotheses. It involves visualizations, summary statistics, and data profiling techniques to uncover patterns, relationships, and interesting features. It helps generate hypotheses for further analysis"

# %%
#Exploratory Analysis here

import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
df['CRASH DATE'] = pd.to_datetime(df['CRASH DATE'])
df['YearMonth'] = df['CRASH DATE'].dt.to_period('M')
crashes_per_month = df.groupby('YearMonth').size()

# Plotting the number of crashes over time (monthly)
plt.figure(figsize=(10, 6))
crashes_per_month.plot(kind='line', marker='o', color='b')

# Adding labels and title
plt.title('Number of Crashes Over Time (Monthly)')
plt.xlabel('Month')
plt.ylabel('Number of Crashes')

# Show plot
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df['Year'] = df['CRASH DATE'].dt.year
crashes_per_year = df.groupby('Year').size()
# Plotting the number of crashes over time (yearly) using a bar plot
plt.figure(figsize=(10, 6))
crashes_per_year.plot(kind='bar', color='g')

# Adding labels and title
plt.title('Number of Crashes Over Time (Yearly)')
plt.xlabel('Year')
plt.ylabel('Number of Crashes')

# Show plot
plt.grid(axis='y')
plt.tight_layout()
plt.show()

# %%
# Count the number of crashes per borough
borough_counts = df['BOROUGH'].value_counts()

# Plotting the number of crashes per borough as a pie chart
plt.figure(figsize=(10, 6))
plt.pie(borough_counts, labels=borough_counts.index, autopct='%1.1f%%', startangle=90, colors=['skyblue', 'lightcoral', 'lightgreen', 'lightpink', 'lightyellow'])

# Adding labels and title
plt.title('Distribution of Crashes by Borough')

# Show plot
plt.tight_layout()
plt.show()

# %%
# Count the number of crashes per ZIP code
zip_counts = df['ZIP CODE'].value_counts().head(30)  # Consider top 30 ZIP codes for example

# Plotting the number of crashes per ZIP code
plt.figure(figsize=(10, 6))
zip_counts.plot(kind='bar', color='salmon')

# Adding labels and title
plt.title('Top 10 ZIP Codes with Most Crashes')
plt.xlabel('ZIP Code')
plt.ylabel('Number of Crashes')

# Show plot
plt.tight_layout()
plt.show()

# %% [markdown]
# ### **Diagnostic Analysis**
# "Diagnostic analysis aims to understand the cause-and-effect relationships within the data. It investigates the factors or variables that contribute to specific outcomes or behaviors. Techniques such as regression analysis or correlation analysis are commonly used."

# %%
#Diagnostic Analysis here
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
correlation_matrix = df.corr()

# Visualize the correlation matrix using a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-22-8b36a5558fa2>:7: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# ### Key Takeaways
#
# Please write a few bullet points (4-6) that describe the major conclusions you made about your dataset based on your analysis above.

# %% [markdown]
# Through various plot we can see that
# * The zipcode with most accidents is 11207
# * The zipcode with least accidents is 11215
# * The borough with most percent of accidents is Brooklyn
# * The borough with least percent of accidents is Staten Island
# * The year with the most number of crashes is 2020
# * The year with the least number of crashes is 2023
